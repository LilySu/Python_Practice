# %% [markdown]
# <a href="https://colab.research.google.com/github/LilySu/Python_Practice/blob/master/Python_Practice_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class SLinkedList:
    def __init__(self):
        self.head = None

    def listprint(self):
        printval = self.head
        while printval is not None:
            print(printval.data)
            printval = printval.next

listl = SLinkedList()
listl.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

# Link first Node to second node
listl.head.next = e2

# Link second Node to third node
e2.next = e3

listl.listprint()
# Out:
# Mon
# Tue
# Wed

# %%
class ListNode:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def print_LinkedList(self):
        printval = self.head
        while printval is not None:
            print(printval.data)
            printval = printval.next

    def at_Beginning(self, newdata):
        NewNode = ListNode(newdata)
        NewNode.next = self.head
        self.head = NewNode

    def at_End(self, newdata):
        NewNode = ListNode(newdata)
        if self.head is None:
            self.head = NewNode
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = NewNode

l = LinkedList()
l.head = Node("Mon")
n2 = ListNode("Tue")
n3 = ListNode("Wed")
l.head.next = n2
n2.next = n3

l.at_Beginning("Sun")
l.at_End("Thur")
l.print_LinkedList()
# Out:
# Sun
# Mon
# Tue
# Wed
# Thur

# %%
class ListNode:
    def __init__(self, data=None):
        self.data = data
        self.next = None
    
class LinkedList:
    def __init__(self):
        self.head = None

    def printll(self):
        printl = self.head
        while printl:
            print(printl.data)
            printl = printl.next

l = LinkedList()
l.head = ListNode("Mon")
e2 = ListNode("Tue")
e3 = ListNode("Wed")

l.head.next = e2
e2.next = e3

l.printll()
# Out:
# Mon
# Tue
# Wed

# %%
class ListNode:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printll(self):
        printl = self.head
        while printl:
            print(printl.data)
            printl = printl.next

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.printll()
# Out:
# Mon
# Tue
# Wed

# %%
class ListNode:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printll(self):
        printl = self.head
        while printl:
            print(printl.data)
            printl = printl.next

l = LinkedList()
l.head = ListNode("Mon")
e2 = ListNode("Tue")
e3 = ListNode("Wed")

l.head.next = e2
e2.next = e3

l.printll()
# Out:
# Mon
# Tue
# Wed

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printll(self):
        printl = self.head
        while printl:
            print(printl.data)
            printl = printl.next

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.printll()
# Out:
# Mon
# Tue
# Wed

# %%
class ListNode:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printll(self):
        printl = self.head
        while printl:
            print(printl.data)
            printl = printl.next

    def insert_at_beginning(self, new_data):
        new_node = ListNode(new_data)
        new_node.next = self.head
        self.head = new_node

    def insert_at_end(self, new_data):
        new_node = ListNode(new_data)
        if not self.head:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node


l = LinkedList()
l.head = ListNode("Mon")
e2 = ListNode("Tue")
e3 = ListNode("Wed")

l.head.next = e2
e2.next = e3

l.insert_at_beginning("Sun")
l.insert_at_end("Thur")
l.printll()

# %%
class Node():
    def __init__(self, data= None):
        self.data = data
        self.next = None

class LinkedList():
    def __init__(self):
        self.head = None

    def printLinkedList(self):
        print_obj = self.head
        while print_obj:
            print(print_obj.data)
            print_obj = print_obj.next

    def insertBeg(self, newData):
        newNode = Node(newData)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next is not None:
            last = last.next
        last.next = newNode            

l = LinkedList()
l.head = Node("mon")
e2 = Node("tue")
e3 = Node("wed")

l.head.next = e2
e2.next = e3
l.insertBeg("sun")
l.insertEnd("thur")
l.printLinkedList()

# %%
class Node():
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList():
    def __init__(self):
        self.head = None

    def printLL(self):
        print_obj = self.head
        while print_obj:
            print(print_obj.data)
            print_obj = print_obj.next

    def insertFront(self, newData):
        newNode = Node(newData)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next is not None:
            last = last.next
        last.next = newNode

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")
l.head.next = e2
e2.next = e3

l.insertFront("Sun")
l.insertEnd("Thur")
l.printLL()

# %%
class Node():
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList():
    def __init__(self):
        self.head = None

    def printLinkedList(self):
        printll = self.head
        while printll:
            print(printll.data)
            printll = printll.next

    def insertBeginning(self, newData):
        newNode = Node(newData)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next is not None:
            last = last.next
        last.next = newNode


l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.insertBeginning("Sun")
l.insertEnd("Thur")
l.printLinkedList()

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def printLinked(self):
        printobj = self.head
        while printobj:
            print(printobj.data)
            printobj = printobj.next

    def insertBeginning(self, newData):
        newNode = Node(newData)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return 
        last = self.head
        while last.next:
            last = last.next
        last.next = newNode

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.insertBeginning("Sun")
l.insertEnd("Thur")

l.printLinked()

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printLinkedList(self):
        printobj = self.head
        while printobj:
            print(printobj.data)
            printobj = printobj.next

    def insertBeg(self, newdata):
        newNode = Node(newdata)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newdata):
        newNode = Node(newdata)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = newNode

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.insertBeg("Sun")
l.insertEnd("Thur")

l.printLinkedList()

# %%
class Node:
    def __init__(self,data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printLL(self):
        printo = self.head
        while printo:
            print(printo.data)
            printo = printo.next
        
    def insertBeg(self, newData):
        newNode = Node(newData)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = newNode

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.insertBeg("Sun")
l.insertEnd("Thur")

l.printLL()class Node:
    def __init__(self,data=None):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def printLL(self):
        printo = self.head
        while printo:
            print(printo.data)
            printo = printo.next
        
    def insertBeg(self, newData):
        newNode = Node(newData)
        newNode.next = self.head
        self.head = newNode

    def insertEnd(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = newNode

l = LinkedList()
l.head = Node("Mon")
e2 = Node("Tue")
e3 = Node("Wed")

l.head.next = e2
e2.next = e3

l.insertBeg("Sun")
l.insertEnd("Thur")

l.printLL()

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        node = Node(data, self.head)
        self.head = node

    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return

        iterator = self.head
        llstr = ''
        while iterator:
            llstr += str(iterator.data) + "-->"
            iterator = iterator.next
        print(llstr)

    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data, None)
            return

        iterator = self.head
        while iterator.next:
            iterator = iterator.next
        iterator.next = Node(data, None)

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)

    def get_length(self):
        count=0
        iterator = self.head
        while iterator:
            count += 1
            iterator = iterator.next
        return count

if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_beginning(5)
    ll.insert_at_beginning(89)
    ll.insert_at_end(7)
    ll.insert_values(["banana", "mango","grapes","orange"])
    ll.print()

# %%
class ListNode:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):# inserts data in beginning of linked list
        node = ListNode(data, self.head) # create node element, the next value is head
        self.head = node

    def printll(self):
        if self.head is None: # if I have a blank linked list
            print("Linked List is empty")
            return
        
        itr = self.head
        linkedlist_string = ''
        while itr:
            linkedlist_string += str(itr.data) + '-->'
            itr = itr.next
        print(linkedlist_string)

    def insert_at_end(self,data):
        if self.head is None: # if linked list is blank
            self.head = ListNode(data, None) # insert to head, next is null
            return

        itr = self.head
        while itr.next:
            itr = itr.next

        itr.next = ListNode(data, None)

    def insert_values(self, data_list): # input a list, get a linked list back
        self.head = None # wipe out everything
        for data in data_list:
            self.insert_at_end(data)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next

        return count

    def remove_at(self, index):
        if (index < 0) or (index >= self.get_length()):
            raise Exception("Invalid index")
        if index == 0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1: # stop at previous element
                itr.next = itr.next.next
                break 
            itr = itr.next
            count += 1
    
    def insert_at(self, index, data):
        if index < 0 or index > self.get_length():
            raise Exception("Invalid Index")

        if index == 0:
            self.insert_at_beginning(data)
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                node = ListNode(data, itr.next)
                itr.next = node
                break
            itr = itr.next
            count += 1

    def insert_after_value(self, data_after, data_to_insert):
        # search for first occurrence of data_after value in linked list
        itr = self.head
        count = 0
        while itr.data != data_after:
            count += 1
            itr = itr.next
        # now insert data_to_insert after data_after node
        self.insert_at(count, data_to_insert)

    def remove_by_value(self, data):
        # remove first node that contains data
        count = 0
        itr = self.head
        while itr.data != data:
            count += 1
            itr = itr.next
        self.remove_at(count)

if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_beginning(5)
    ll.insert_at_beginning(28)
    ll.insert_at_end(79)
    ll.insert_at_end(1)
    ll.insert_at_end(9876)
    ll.insert_values(["banana", "mango","grapes","orange"])
    # ll.remove_at(2)
    ll.insert_at(0,"figs")
    ll.printll()
    ll.insert_at(2, "jackfruit")
    ll.insert_after_value("orange","pear")
    ll.printll()
    # print("length:", ll.get_length())
    ll.remove_at(2)
    ll.remove_by_value("figs")
    ll.printll()

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def printll(self):
        itr = self.head
        while itr:
            print(itr.data)
            itr = itr.next

ll = LinkedList()
v = Node(3)
ll.head = Node(25, v)
ll.printll()
# Out:
# 25
# 3

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return

        itr = self.head
        llstr=''
        while itr:
            llstr += str(itr.data) + '-->'
            itr = itr.next

        print(llstr)

    def insert_at_beginning(self, data):
        itr = Node(data, self.head)
        self.head = itr

    def insert_at_end(self, data):
        itr = Node(data, None)
        if self.head == None:
            self.head = itr
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = itr

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next
        return count

    def remove_at(self, index):
        if index < 0 or index >= self.get_length():
            raise Exception("Invalid index")

        if index==0:
            self.head = self.head.next
            return

if __name__=='__main__':
    ll = LinkedList()
    ll.insert_at_beginning('apple')
    ll.insert_at_beginning('pear')
    ll.insert_at_end('peach')
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.remove_at(2)
    ll.print()

# %%
class ListNode:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):# inserts data in beginning of linked list
        node = ListNode(data, self.head) # create node element, the next value is head
        self.head = node

    def printll(self):
        if self.head is None: # if I have a blank linked list
            print("Linked List is empty")
            return
        
        itr = self.head
        linkedlist_string = ''
        while itr:
            linkedlist_string += str(itr.data) + '-->'
            itr = itr.next
        print(linkedlist_string)

    def insert_at_end(self,data):
        if self.head is None: # if linked list is blank
            self.head = ListNode(data, None) # insert to head, next is null
            return

        itr = self.head
        while itr.next:
            itr = itr.next

        itr.next = ListNode(data, None)

    def insert_values(self, data_list): # input a list, get a linked list back
        self.head = None # wipe out everything
        for data in data_list:
            self.insert_at_end(data)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next

        return count

    def remove_at(self, index):
        if (index < 0) or (index >= self.get_length()):
            raise Exception("Invalid index")
        if index == 0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1: # stop at previous element
                itr.next = itr.next.next
                break 
            itr = itr.next
            count += 1
    
    def insert_at(self, index, data):
        if index < 0 or index > self.get_length():
            raise Exception("Invalid Index")

        if index == 0:
            self.insert_at_beginning(data)
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                node = ListNode(data, itr.next)
                itr.next = node
                break
            itr = itr.next
            count += 1

    def insert_after_value(self, data_after, data_to_insert):
        # search for first occurrence of data_after value in linked list
        itr = self.head
        count = 0
        while itr.data != data_after:
            count += 1
            itr = itr.next
        # now insert data_to_insert after data_after node
        self.insert_at(count, data_to_insert)

    def remove_by_value(self, data):
        # remove first node that contains data
        count = 0
        itr = self.head
        while itr.data != data:
            count += 1
            itr = itr.next
        self.remove_at(count)

if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_beginning(5)
    ll.insert_at_beginning(28)
    ll.insert_at_end(79)
    ll.insert_at_end(1)
    ll.insert_at_end(9876)
    ll.insert_values(["banana", "mango","grapes","orange"])
    # ll.remove_at(2)
    ll.insert_at(0,"figs")
    ll.printll()
    ll.insert_at(2, "jackfruit")
    ll.insert_after_value("orange","pear")
    ll.printll()
    # print("length:", ll.get_length())
    ll.remove_at(2)
    ll.remove_by_value("figs")
    ll.printll()

# %%
class Node:
    def __init__(self, data, next):
        self.data = data
        self.next = next

class LinkedList:
    def __init(self):
        self.head = None

    def printll(self):
        if self.head is None:
            print("Linked List Empty")
            return
        printobj = self.head
        printstr = ''
        while printobj:
            printstr += str(printobj.data) + '-->'
            printobj = printobj.next
        print(printstr)

    def insert_beg(self, newData):
        newNode = Node(newData, self.head)
        self.head = newNode

    def insert_end(self, newData):
        newNode = Node(newData, None)
        if self.head is None:
            self.head = newNode
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = newNode

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_end(data)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next
        return count

    def remove_at(self, index):
        if index < 0 and index >= self.get_length():
            raise Exception("Invalid Index")
        if index == 0:
            self.head = self.head.next
        counter = 0
        currentNode = self.head
        while currentNode:
            if counter == index - 1:
                 currentNode.next = currentNode.next.next
                 break
            currentNode = currentNode.next
            counter += 1

    def insert_at(self, index, data):
        if index < 0 and index >= self.get_length():
            raise Exception("Invalid Index")
        if index == 0:
            self.insert_beg(data)
            return 
            

ll = LinkedList()
e3 = Node("Guava", None)
e2 = Node("Avocado", e3)
ll.head = Node("Berry", e2)

ll.insert_values(["Banana", "Mango","Grapes"])
# ll.insert_beg("Peach")
# ll.insert_end("Pear")
# ll.insert_end("Apple")
ll.remove_at(2)
ll.printll()
ll.get_length()

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_beg(self, newdata):
        newNode = Node(newdata, self.head)
        self.head = newNode

    def printll(self):
        if self.head is None:
            print("Linked List is empty")
            return
        printstr = ''
        printobj = self.head
        while printobj:
            printstr += str(printobj.data) + '-->'
            printobj = printobj.next
        print(printstr)

    def insert_end(self, newdata):
        if self.head is None:
            self.head = Node(newdata)
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = Node(newdata)

    def get_length(self):
        count = 0
        if self.head is None:
            return 0
        current = self.head
        while current:
            current = current.next
            count += 1
        return count

    def insert_by_index(self, index, newdata):
        if index < 0 or index >= self.get_length():
            raise Exception("Invalid Index")
        if index == 0:
            self.insert_beg(newdata)
            return
        count = 0
        current = self.head
        while count != (index-1):
            current = current.next
            count += 1
        newNode = Node(newdata, current.next)
        current.next = newNode



ll = LinkedList()

e2 = Node("Peach", None)
ll.head = Node("Apple", e2)

ll.insert_beg("Mon")
ll.insert_beg("Sun")

ll.insert_end("Potato")

ll.insert_by_index(0, "Peas")
ll.insert_by_index(2, "Pizza")
ll.printll()
ll.get_length()

# %%
class Node:
    def __init__(self, data, next):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def print(self):
        if self.head is None:
            print("Linked List Empty")
            return
        
        printstr = ''
        printobj = self.head
        while printobj:
            printstr += str(printobj.data) + '-->'
            printobj = printobj.next
        print(printstr)

    def insert_beg(self, newData):
        newNode = Node(newData, self.head)
        self.head = newNode

    def insert_end(self, newData):
        if self.head is None:
            self.head = Node(newData, None)
            return

        last = self.head
        while last.next:
            last = last.next
        last.next = Node(newData, None)

    def get_length(self):
        count = 0
        current = self.head
        while current:
            current = current.next
            count += 1
        return count

    def retrieve_item_at_index_insert_at_end(self, index):
        if index < 0 or index >= self.get_length():
            raise Exception("Invalid Index")
        count = 0
        current = self.head
        while index != count:
            current = current.next
            count += 1
        return self.insert_end(current.data)

    def remove_at(self, index):
        if index < 0 or index >= self.get_length():
            raise Exception("Invalid Index")
        if index == 0:
            self.head = self.head.next
            return
        count = 0
        current = self.head
        while current:
            if count == (index - 1):
                current.next = current.next.next
                break
            count += 1
            current = current.next

    def insert_after_value(self, data_after, data_to_insert):
        # Search for first occurrence of data_after value in linked list
        if self.head is None:
            self.head = Node(data_to_insert)
        current = self.head
        while current.data != data_after:
            current = current.next
        current.next = Node(data_after, current.next.next)




ll = LinkedList()
e2 = Node("Orange",None)
ll.head = Node("bath", e2)
ll.insert_beg("Cheese")
ll.insert_end("Cake")
ll.retrieve_item_at_index_insert_at_end(2)
ll.remove_at(1)
ll.print()
ll.get_length()

# %%
class Node:
    def __init__(self, data=None, next=None, prev=None):
        self.data = data
        self.next = next
        self.prev = prev

class LinkedList:
    def __init__(self):
        self.head = None

    # def print(self):
    #     if self.head is None:
    #         return "The Linked List is Empty"
    #     printstr = ''
    #     itr = self.head
    #     while itr:
    #         printstr += str(itr.data) + '-->'
    #         itr = itr.next
    #     print(printstr)

    # def insert_beg(self, newData):
    #     itr = Node(newData, self.head)
    #     self.head = itr

    # def insert_end(self, newData):
    #     if self.head is None:
    #         self.head = Node(newData, None)
    #     itr = self.head
    #     while itr.next:
    #         itr = itr.next
    #     itr.next = Node(newData, None)

    # def get_len(self):
    #     counter = 0
    #     if self.head is None:
    #         return 0
    #     itr = self.head
    #     while itr:
    #         itr = itr.next
    #         counter += 1
    #     return counter

    # def insert_at_index(self, index, newData):
    #     if index < 0 or index > self.get_len():
    #         raise Exception("Index Out of Range")
    #     if index == 0:
    #         self.insert_beg(newData)
    #         return
    #     itr = self.head
    #     counter = 0
    #     while itr:
    #         if counter == index-1:
    #             newNode = Node(newData, itr.next)
    #             itr.next = newNode
    #         itr = itr.next
    #         counter += 1
    
    # def remove_at_index(self, index):
    #     if index < 0 or index > self.get_len():
    #         raise Exception("Index Out of Range")
    #     if index == 0:
    #         self.head = self.head.next
    #     counter = 0
    #     itr = self.head
    #     while itr:
    #         if counter == index-1:
    #             itr.next = itr.next.next
    #             break
    #         itr = itr.next
    #         counter += 1
    
    def print_forward(self):
        # prints list in forward direction using node.next
        printobj = self.head
        while printobj:
            print(printobj.data)
            printobj = printobj.next
    
    def print_backwards(self):
        # print linked list in reverse direction. Use node.prev
        printobj = self.head
        while printobj.next:
            printobj = printobj.next
        print(printobj.data)
        while printobj.prev:
            print(printobj.prev.data)
            printobj = printobj.prev
        print(self.head.data)
        



ll = LinkedList()  
e3 = Node("Wed", None, e2)
e2 = Node("Tue",e3, ll.head)      
ll.head = Node("Mon", e2, None)
# ll.insert_beg("Sun")
# ll.insert_end("Wed")
# ll.insert_at_index(3, "Insert at Index 1")
# ll.remove_at_index(0)
# ll.print()
# ll.get_len()

ll.print_backwards()

# %%
class Node:
    def __init__(self, data, next):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def print(self):
        if self.head is None:
            return "Linked List is Empty"
        pointer = self.head
        printstr = ''
        while pointer:
            printstr += str(pointer.data) + '-->'
            pointer = pointer.next
        return printstr

    def insert_beg(self, data):
        newNode = Node(data, self.head)
        self.head = newNode

    def insert_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return
        pointer = self.head
        while pointer.next:
            pointer = pointer.next
        pointer.next = Node("Thur", None)

    def get_length(self):
        if self.head is None:
            return 0
        counter = 0
        pointer = self.head
        while pointer:
            pointer = pointer.next
            counter += 1
        return counter

    def delete_at_index(self, index):
        if index < 0 and index > self.get_length():
            raise Exception("Index out of range")
        if index == 0:
            self.head = self.head.next
            return
        counter = 0
        pointer = self.head
        while pointer:
            if counter == index - 1:
                pointer.next = pointer.next.next
                return
            pointer = pointer.next
            counter += 1

    def insert_at_index(self, index, data):
        if index < 0 and index > self.get_length():
            raise Exception("Index out of range")
        if index == 0:
            self.insert_beg(data)
        counter = 0
        pointer = self.head
        while pointer:
            if counter == index - 1:
                node = Node(data, pointer.next)
                pointer.next = node
                return
            pointer = pointer.next
            counter += 1


ll = LinkedList()
e3 = Node("Wed", None)
e2 = Node("Tue", e3)
ll.head = Node("Mon", e2)

ll.insert_beg("Sun")
ll.insert_end("Thur")
ll.insert_at_index(2,"Inserted")
# ll.delete_at_index(0)
ll.print()
# ll.get_length()
# Out:
# 'Sun-->Mon-->Inserted-->Tue-->Wed-->Thur-->'

# %%
class Node:
    def __init__(self, data, next):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def print(self):
        itr = self.head
        pstr = ''
        while itr:
            pstr += str(itr.data) + '-->'
            itr = itr.next
        print(pstr)

    def insert_beg(self, data):
        newNode = Node(data, self.head)
        self.head = newNode

    def insert_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return
        itr = self.head
        while itr.next:
            itr = itr.next
        itr.next = Node(data, None)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            itr = itr.next
            count += 1
        return count

    def delete_at_index(self, index):
        if index < 0 or index > self.get_length():
            raise Exception("Index out of range")
        if index == 0:
            self.head = self.head.next
        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                itr.next = itr.next.next
            itr = itr.next
            count += 1

    def insert_at_index(self, index, data):
        if index < 0 or index > self.get_length():
            raise Exception("Index out of range")
        count = 0 
        itr = self.head
        while itr:
            if count == index - 1:
                newNode = Node(data, itr.next)
                itr.next = newNode
            itr = itr.next
            count += 1


ll = LinkedList()
e3 = Node("Wed", None)
e2 = Node("Tue", e3)
ll.head = Node("Mon", e2)

ll.insert_beg("Sun")
ll.insert_end("Thur")
ll.insert_at_index(2,"Inserted")
ll.delete_at_index(0)
ll.print()
ll.get_length()
# Out:
# Mon-->Inserted-->Tue-->Wed-->Thur-->
# 5

# %%
class Node:
    def __init__(self, data, next):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None
    
    def print(self):
        if self.head is None:
            return "Linked List Empty"
        printstr = ''
        printobj = self.head
        while printobj:
            printstr += str(printobj.data) + '-->'
            printobj = printobj.next
        print(printstr)

    def get_length(self):
        if self.head is None:
            return 0
        counter = 0
        pointer = self.head
        while pointer:
            pointer = pointer.next
            counter += 1
        return counter

    def insert_beg(self, data):
        newNode = Node(data, self.head)
        self.head = newNode

    def insert_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return
        pointer = self.head
        while pointer.next:
            pointer = pointer.next
        pointer.next = Node(data, None)

    def remove_at_index(self, index):
        if index < 0 or index >= self.get_length():
            raise Exception("Index out of bounds")
        if index == 0:
            self.head = self.head.next
        counter = 0
        pointer = self.head
        while pointer:
            if counter == index - 1:
                pointer.next = pointer.next.next
            pointer = pointer.next
            counter += 1

    def insert_at_index(self, index, data):
        if index < 0 or index >= self.get_length():
            raise Exception("Index out of bounds")
        if index == 0:
            self.insert_beg(data)
        counter = 0
        pointer = self.head
        while pointer:
            if counter == index - 1:
                newNode = Node(data, pointer.next)
                pointer.next = newNode
            pointer = pointer.next
            counter += 1

l = LinkedList()
e3 = Node("Con", None)
e2 = Node("Bon", e3)
l.head = Node("Mon", e2)

# l.remove_at_index(3)
# l.insert_beg("Son")
# l.insert_end("Gon")
l.insert_at_index(1, "Piz")

l.print()
l.get_length()
# Out:
# Mon-->Piz-->Bon-->Con-->
# 4
